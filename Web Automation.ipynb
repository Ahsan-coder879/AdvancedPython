# %%
from selenium import webdriver
import time

from selenium.webdriver.common.by import By

browser = webdriver.Chrome()
signButtonXpath = "/html/body/div[1]/div/div/div[1]/div[1]/div[1]/div/div/div/div[2]/div[2]/button"
emailFieldXpath = "/html/body/div[1]/div/div/div[1]/div[1]/div[1]/div[1]/div/div[2]/div/div[3]/div/div[1]/input"

browser.get("https://www.geeksforgeeks.org/python/how-to-install-selenium-in-python/")
time.sleep(1.5)
signInButton = browser.find_element(By.XPATH, signButtonXpath)
print("Clicking on Sign In button")
signInButton.click()
time.sleep(2)
emailField = browser.find_element(By.XPATH, emailFieldXpath)
emailField.send_keys("ahmadisloggingin")

time.sleep(5)
print("Done")
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[2], line 12
#      10 browser.get("https://www.geeksforgeeks.org/python/how-to-install-selenium-in-python/")
#      11 time.sleep(1.5)
# ---> 12 signInButton = browser.find_element(By.XPATH, signButtonXpath)
#      13 print("Clicking on Sign In button")
#      14 signInButton.click()
#
# File D:\Advacedpython\Python\AdvancedPython\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:823, in WebDriver.find_element(self, by, value)
#     820         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     821     return elements[0]
# --> 823 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File D:\Advacedpython\Python\AdvancedPython\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:450, in WebDriver.execute(self, driver_command, params)
#     447 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     449 if response:
# --> 450     self.error_handler.check_response(response)
#     451     response["value"] = self._unwrap_value(response.get("value", None))
#     452     return response
#
# File D:\Advacedpython\Python\AdvancedPython\.venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=147.0.7727.55); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff7631e0295+146d5]
# 	chromedriver!GetHandleVerifier [0x7ff7631e0300+14740]
# 	chromedriver!(No symbol) [0x7ff762f4d7cd]
# 	chromedriver!(No symbol) [0x7ff762f38842]
# 	chromedriver!(No symbol) [0x7ff762f5f0b1]
# 	chromedriver!(No symbol) [0x7ff762fd70b0]
# 	chromedriver!(No symbol) [0x7ff762ff40e2]
# 	chromedriver!(No symbol) [0x7ff762f99018]
# 	chromedriver!(No symbol) [0x7ff762f99f03]
# 	chromedriver!GetHandleVerifier [0x7ff7634f5949+329d89]
# 	chromedriver!GetHandleVerifier [0x7ff7634efe96+3242d6]
# 	chromedriver!GetHandleVerifier [0x7ff763513102+347542]
# 	chromedriver!GetHandleVerifier [0x7ff7631fd425+31865]
# 	chromedriver!GetHandleVerifier [0x7ff76320605c+3a49c]
# 	chromedriver!GetHandleVerifier [0x7ff7631e9684+1dac4]
# 	chromedriver!GetHandleVerifier [0x7ff7631e9836+1dc76]
# 	chromedriver!GetHandleVerifier [0x7ff7631ce347+2787]
# 	KERNEL32!BaseThreadInitThunk [0x7ffbe678257d+1d]
# 	ntdll!RtlUserThreadStart [0x7ffbe86aaf08+28]
