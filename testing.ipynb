# %%
import requests as r
from bs4 import BeautifulSoup as bs
import pandas as pd

h1_text = ""

tableresponse = r.get("https://www.scrapethissite.com/pages/forms/")
with open("TableData.html","w") as file:
    file.write(tableresponse.text)
with open("TableData.html","r") as file:
    sourceCode = file.read()
    soup = bs(sourceCode,"html.parser")
    tableData = soup.find_all("tr")
    tableDataList = []
    if tableresponse == 1:
            h1_text = soup.find("h1").get_text().strip()
    for eachRow in tableData:
        cell = eachRow.find_all(["td","th"])
        singleRow=[]
        for eachCell in cell:
            singleRow.append(eachCell.get_text().strip())
        tableDataList.append(singleRow)
tableDF = pd.DataFrame(tableDataList[1:],columns=tableDataList[0])
print("H1:", h1_text)
tableDF
# Out:
# H1:
#                 Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0           Boston Bruins  1990   44     24             0.55            299
# 1          Buffalo Sabres  1990   31     30            0.388            292
# 2          Calgary Flames  1990   46     26            0.575            344
# 3      Chicago Blackhawks  1990   49     23            0.613            284
# 4       Detroit Red Wings  1990   34     38            0.425            273
# 5         Edmonton Oilers  1990   37     37            0.463            272
# 6        Hartford Whalers  1990   31     38            0.388            238
# 7       Los Angeles Kings  1990   46     24            0.575            340
# 8   Minnesota North Stars  1990   27     39            0.338            256
# 9      Montreal Canadiens  1990   39     30            0.487            273
# 10      New Jersey Devils  1990   32     33              0.4            272
# ...

# %%
import pandas as pd
import requests as r
response = r.get("https://fake-json-api.mock.beeceptor.com/users")
# print(response.json())
userResponse = response.json()
userDatadf = pd.DataFrame(userResponse)
userDatadf
# Out:
#    id                                               name  \
# 0   1                                         Eula Mante
# 1   2  Marta Faker Attribute Error: person.astName is...
# 2   3                                        Diego Wyman
# 3   4                                    Jennyfer Zemlak
# 4   5                                         Van Torphy
# 5   6                                      Arianna Mante
# 6   7                                        Holly Bosco
# 7   8                                 Dexter Oberbrunner
# 8   9                                        Olen Pouros
# 9  10                                       Brayan Boyer
#
#                               company            username  \
# 0         Rippin, Witting and Langosh             Elmore7
# 1            Pagac, Barrows and Boyer   Polly.Cruickshank
# 2          Koelpin, Hickle and Kohler     Anderson.Koss36
# 3        Waters, Goodwin and Turcotte      Hilton.Streich
# ...

# %%
url = 'https://api.escuelajs.co/api/v1/auth/login'
h = {
    'Content-Type': 'application/json'
}
accesToken = ""
credentials = {"email":"john@mail.com","password":"changeme"}
response = r.post(url,json = credentials,headers=h)
print(response.json())
postresponse = response.json()
accessToken = postresponse['access_token']
print(accessToken)
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ5MDMyNywiZXhwIjoxNzc3MjE4MzI3fQ.CgeiAMiqF7_0D8ruy-IOxt4BhP5CC_Ke05KAlD-ceVY', 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ5MDMyNywiZXhwIjoxNzc1NTI2MzI3fQ.DkMbPupT2aRnD_-qCom_hSA4c1CHtI0bCsPSApsWkts'}
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ5MDMyNywiZXhwIjoxNzc3MjE4MzI3fQ.CgeiAMiqF7_0D8ruy-IOxt4BhP5CC_Ke05KAlD-ceVY

# %%
userProfileUrl = "https://api.escuelajs.co/api/v1/auth/profile"
newheader = {
    "Authorization": f"Bearer {accessToken}"
}
profielResponse = r.get(userProfileUrl,headers=newheader)
print(profielResponse.json())
# Out:
# {'id': 1, 'email': 'john@mail.com', 'password': 'changeme', 'name': 'Jhon', 'role': 'customer', 'avatar': 'https://i.imgur.com/LDOO4Qs.jpg', 'creationAt': '2026-04-06T03:15:21.000Z', 'updatedAt': '2026-04-06T03:15:21.000Z'}
